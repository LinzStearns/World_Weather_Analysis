# %%
# Import the dependencies.
from citipy import citipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 769

# %%
# Import the request library.
import requests

from datetime import datetime
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # Adding Weather description
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | vila franca do campo
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | tual
# Processing Record 11 of Set 1 | markova
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | husavik
# Processing Record 14 of Set 1 | sitka
# Processing Record 15 of Set 1 | mehamn
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | hermanus
# Processing Record 18 of Set 1 | katsuura
# Processing Record 19 of Set 1 | coquimbo
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | nuuk
# Processing Record 22 of Set 1 | bengkulu
# Processing Record 23 of Set 1 | quatre cocos
# Processing Record 24 of Set 1 | carnarvon
# Processing Record 25 of Set 1 | norman wells
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | zarautz
# Processing Record 28 of Set 1 | udachnyy
# Processing Record 29 of Set 1 | staraya poltavka
# Processing Record 30 of Set 1 | alampur
# Processing Record 31 of Set 1 | antalaha
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | rikitea
# Processing Record 34 of Set 1 | caborca
# Processing Record 35 of Set 1 | bambous virieux
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | paita
# Processing Record 38 of Set 1 | azare
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | yeniseysk
# Processing Record 41 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 1 | hasaki
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | sabang
# Processing Record 45 of Set 1 | san patricio
# Processing Record 46 of Set 1 | solnechnyy
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | kaabong
# Processing Record 49 of Set 1 | leca da palmeira
# Processing Record 50 of Set 1 | deputatskiy
# Processing Record 1 of Set 2 | diffa
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | leningradskiy
# Processing Record 5 of Set 2 | sursk
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | narsaq
# Processing Record 8 of Set 2 | panuco
# Processing Record 9 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 2 | faanui
# Processing Record 11 of Set 2 | sagar
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | nuevo casas grandes
# Processing Record 16 of Set 2 | telemaco borba
# Processing Record 17 of Set 2 | barabinsk
# Processing Record 18 of Set 2 | oriximina
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | mandurah
# Processing Record 21 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | kiruna
# Processing Record 24 of Set 2 | sale
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | geraldton
# Processing Record 27 of Set 2 | albany
# Processing Record 28 of Set 2 | naica
# Processing Record 29 of Set 2 | riachao das neves
# Processing Record 30 of Set 2 | mercedes
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | raga
# Processing Record 33 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 2 | faya
# Processing Record 35 of Set 2 | warrensburg
# Processing Record 36 of Set 2 | rjukan
# Processing Record 37 of Set 2 | mataura
# Processing Record 38 of Set 2 | peniche
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | xique-xique
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | mildura
# Processing Record 44 of Set 2 | ruteng
# Processing Record 45 of Set 2 | wonthaggi
# Processing Record 46 of Set 2 | bilma
# Processing Record 47 of Set 2 | kudahuvadhoo
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 2 | esperance
# Processing Record 1 of Set 3 | sola
# Processing Record 2 of Set 3 | wuwei
# Processing Record 3 of Set 3 | agadez
# Processing Record 4 of Set 3 | mhlume
# Processing Record 5 of Set 3 | kirakira
# Processing Record 6 of Set 3 | barcelos
# Processing Record 7 of Set 3 | kvareli
# Processing Record 8 of Set 3 | cabedelo
# Processing Record 9 of Set 3 | shingu
# Processing Record 10 of Set 3 | vardo
# Processing Record 11 of Set 3 | prince rupert
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | eyl
# Processing Record 14 of Set 3 | saint-philippe
# Processing Record 15 of Set 3 | lasa
# Processing Record 16 of Set 3 | iranshahr
# Processing Record 17 of Set 3 | touros
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | thinadhoo
# Processing Record 21 of Set 3 | zhitikara
# City not found. Skipping...
# Processing Record 22 of Set 3 | kinsale
# Processing Record 23 of Set 3 | songjianghe
# Processing Record 24 of Set 3 | broken hill
# Processing Record 25 of Set 3 | isangel
# Processing Record 26 of Set 3 | coahuayana
# Processing Record 27 of Set 3 | bandarbeyla
# Processing Record 28 of Set 3 | namibe
# Processing Record 29 of Set 3 | yakeshi
# Processing Record 30 of Set 3 | havelock
# Processing Record 31 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 3 | kruisfontein
# Processing Record 33 of Set 3 | kyra
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | kuzino
# Processing Record 36 of Set 3 | tura
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | cascais
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | iwanai
# Processing Record 41 of Set 3 | kishcha
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | biak
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | desterro
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | pochutla
# Processing Record 48 of Set 3 | yulara
# Processing Record 49 of Set 3 | dvinskoy
# Processing Record 50 of Set 3 | cape town
# Processing Record 1 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 2 of Set 4 | raudeberg
# Processing Record 3 of Set 4 | provideniya
# Processing Record 4 of Set 4 | marsa matruh
# Processing Record 5 of Set 4 | pacific grove
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | chapais
# Processing Record 8 of Set 4 | te anau
# Processing Record 9 of Set 4 | kaitangata
# Processing Record 10 of Set 4 | brae
# Processing Record 11 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 12 of Set 4 | santa marta
# Processing Record 13 of Set 4 | qaanaaq
# Processing Record 14 of Set 4 | puerto leguizamo
# Processing Record 15 of Set 4 | nikolaevo
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | makakilo city
# Processing Record 18 of Set 4 | celestun
# Processing Record 19 of Set 4 | saskylakh
# Processing Record 20 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 21 of Set 4 | afsin
# Processing Record 22 of Set 4 | yerbogachen
# Processing Record 23 of Set 4 | lima
# Processing Record 24 of Set 4 | gallup
# Processing Record 25 of Set 4 | galesong
# Processing Record 26 of Set 4 | soyo
# Processing Record 27 of Set 4 | pudozh
# Processing Record 28 of Set 4 | cidreira
# Processing Record 29 of Set 4 | cap malheureux
# Processing Record 30 of Set 4 | awbari
# Processing Record 31 of Set 4 | mahebourg
# Processing Record 32 of Set 4 | klaksvik
# Processing Record 33 of Set 4 | high rock
# Processing Record 34 of Set 4 | sioux lookout
# Processing Record 35 of Set 4 | mega
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | marsaxlokk
# Processing Record 38 of Set 4 | yanchukan
# City not found. Skipping...
# Processing Record 39 of Set 4 | laem sing
# Processing Record 40 of Set 4 | chokurdakh
# Processing Record 41 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 42 of Set 4 | nanchang
# Processing Record 43 of Set 4 | lafiagi
# Processing Record 44 of Set 4 | santa maria
# Processing Record 45 of Set 4 | nicoya
# Processing Record 46 of Set 4 | belaya gora
# Processing Record 47 of Set 4 | urumqi
# Processing Record 48 of Set 4 | ilebo
# Processing Record 49 of Set 4 | kavaratti
# Processing Record 50 of Set 4 | beringovskiy
# Processing Record 1 of Set 5 | keti bandar
# Processing Record 2 of Set 5 | pedernales
# Processing Record 3 of Set 5 | lincoln
# Processing Record 4 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 5 of Set 5 | kamien pomorski
# Processing Record 6 of Set 5 | kieta
# Processing Record 7 of Set 5 | constitucion
# Processing Record 8 of Set 5 | guiglo
# Processing Record 9 of Set 5 | dingle
# Processing Record 10 of Set 5 | denpasar
# Processing Record 11 of Set 5 | mazagao
# Processing Record 12 of Set 5 | boyolangu
# Processing Record 13 of Set 5 | victoria
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | kulhudhuffushi
# Processing Record 16 of Set 5 | emerald
# Processing Record 17 of Set 5 | broome
# Processing Record 18 of Set 5 | springdale
# Processing Record 19 of Set 5 | grand gaube
# Processing Record 20 of Set 5 | dikson
# Processing Record 21 of Set 5 | ayan
# Processing Record 22 of Set 5 | tabou
# Processing Record 23 of Set 5 | gedo
# Processing Record 24 of Set 5 | tamala
# Processing Record 25 of Set 5 | krasnoselkup
# Processing Record 26 of Set 5 | wanning
# Processing Record 27 of Set 5 | asau
# Processing Record 28 of Set 5 | huntsville
# Processing Record 29 of Set 5 | launceston
# Processing Record 30 of Set 5 | carutapera
# Processing Record 31 of Set 5 | korla
# Processing Record 32 of Set 5 | aykhal
# Processing Record 33 of Set 5 | mweka
# Processing Record 34 of Set 5 | cabo san lucas
# Processing Record 35 of Set 5 | nome
# Processing Record 36 of Set 5 | lethem
# Processing Record 37 of Set 5 | pisco
# Processing Record 38 of Set 5 | masallatah
# Processing Record 39 of Set 5 | tadine
# Processing Record 40 of Set 5 | cootamundra
# Processing Record 41 of Set 5 | gabaldon
# Processing Record 42 of Set 5 | umm lajj
# Processing Record 43 of Set 5 | hamilton
# Processing Record 44 of Set 5 | north charleston
# Processing Record 45 of Set 5 | kaeo
# Processing Record 46 of Set 5 | santa cruz
# Processing Record 47 of Set 5 | kabanjahe
# Processing Record 48 of Set 5 | santa rosa
# Processing Record 49 of Set 5 | ponta do sol
# Processing Record 50 of Set 5 | biltine
# Processing Record 1 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 6 | la ronge
# Processing Record 3 of Set 6 | walvis bay
# Processing Record 4 of Set 6 | zeerust
# Processing Record 5 of Set 6 | horsham
# Processing Record 6 of Set 6 | havoysund
# Processing Record 7 of Set 6 | sabha
# Processing Record 8 of Set 6 | ust-kuyga
# Processing Record 9 of Set 6 | tibacuy
# Processing Record 10 of Set 6 | severnyy
# Processing Record 11 of Set 6 | chuy
# Processing Record 12 of Set 6 | lagoa
# Processing Record 13 of Set 6 | rio branco
# Processing Record 14 of Set 6 | gander
# Processing Record 15 of Set 6 | clyde river
# Processing Record 16 of Set 6 | hauterive
# Processing Record 17 of Set 6 | burns lake
# Processing Record 18 of Set 6 | ornskoldsvik
# Processing Record 19 of Set 6 | hambantota
# Processing Record 20 of Set 6 | morro bay
# Processing Record 21 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 6 | santa cruz del sur
# Processing Record 23 of Set 6 | fort nelson
# Processing Record 24 of Set 6 | shaowu
# Processing Record 25 of Set 6 | alofi
# Processing Record 26 of Set 6 | sorong
# Processing Record 27 of Set 6 | akdepe
# Processing Record 28 of Set 6 | shelburne
# Processing Record 29 of Set 6 | athabasca
# Processing Record 30 of Set 6 | orvault
# Processing Record 31 of Set 6 | mareeba
# Processing Record 32 of Set 6 | kuliyapitiya
# Processing Record 33 of Set 6 | billings
# Processing Record 34 of Set 6 | porto belo
# Processing Record 35 of Set 6 | angola
# Processing Record 36 of Set 6 | juanjui
# Processing Record 37 of Set 6 | manhattan
# Processing Record 38 of Set 6 | huesca
# Processing Record 39 of Set 6 | hithadhoo
# Processing Record 40 of Set 6 | baghdad
# Processing Record 41 of Set 6 | valparaiso
# Processing Record 42 of Set 6 | padang
# Processing Record 43 of Set 6 | hokitika
# Processing Record 44 of Set 6 | kahului
# Processing Record 45 of Set 6 | cayenne
# Processing Record 46 of Set 6 | vanavara
# Processing Record 47 of Set 6 | georgetown
# Processing Record 48 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 49 of Set 6 | ust-omchug
# Processing Record 50 of Set 6 | west bay
# Processing Record 1 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 7 | yate
# Processing Record 3 of Set 7 | weligama
# Processing Record 4 of Set 7 | mangochi
# Processing Record 5 of Set 7 | coruripe
# Processing Record 6 of Set 7 | taungdwingyi
# Processing Record 7 of Set 7 | limon
# Processing Record 8 of Set 7 | ixtapa
# Processing Record 9 of Set 7 | navabad
# City not found. Skipping...
# Processing Record 10 of Set 7 | kavieng
# Processing Record 11 of Set 7 | kjollefjord
# Processing Record 12 of Set 7 | daoukro
# Processing Record 13 of Set 7 | pevek
# Processing Record 14 of Set 7 | liliongan
# Processing Record 15 of Set 7 | gushikawa
# Processing Record 16 of Set 7 | pasighat
# Processing Record 17 of Set 7 | arica
# Processing Record 18 of Set 7 | nizwa
# Processing Record 19 of Set 7 | mangai
# Processing Record 20 of Set 7 | komsomolskiy
# Processing Record 21 of Set 7 | kuala krai
# City not found. Skipping...
# Processing Record 22 of Set 7 | vila
# Processing Record 23 of Set 7 | saint george
# Processing Record 24 of Set 7 | barranca
# Processing Record 25 of Set 7 | yeletskiy
# City not found. Skipping...
# Processing Record 26 of Set 7 | vorgashor
# Processing Record 27 of Set 7 | newport
# Processing Record 28 of Set 7 | bom conselho
# Processing Record 29 of Set 7 | sotuta
# Processing Record 30 of Set 7 | peterhead
# Processing Record 31 of Set 7 | iqaluit
# Processing Record 32 of Set 7 | americus
# Processing Record 33 of Set 7 | snasa
# Processing Record 34 of Set 7 | lodja
# Processing Record 35 of Set 7 | lieksa
# Processing Record 36 of Set 7 | weston
# Processing Record 37 of Set 7 | impfondo
# Processing Record 38 of Set 7 | moron
# Processing Record 39 of Set 7 | termiz
# Processing Record 40 of Set 7 | port lincoln
# Processing Record 41 of Set 7 | ponta delgada
# Processing Record 42 of Set 7 | caravelas
# Processing Record 43 of Set 7 | maceio
# Processing Record 44 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 7 | cherskiy
# Processing Record 46 of Set 7 | sao desiderio
# Processing Record 47 of Set 7 | huarmey
# Processing Record 48 of Set 7 | beaverlodge
# Processing Record 49 of Set 7 | adre
# Processing Record 50 of Set 7 | kazerun
# Processing Record 1 of Set 8 | qitaihe
# Processing Record 2 of Set 8 | hays
# Processing Record 3 of Set 8 | olinda
# Processing Record 4 of Set 8 | necochea
# Processing Record 5 of Set 8 | olafsvik
# Processing Record 6 of Set 8 | store heddinge
# Processing Record 7 of Set 8 | laguna
# Processing Record 8 of Set 8 | kilmez
# City not found. Skipping...
# Processing Record 9 of Set 8 | cockburn town
# Processing Record 10 of Set 8 | okhotsk
# Processing Record 11 of Set 8 | zhezkazgan
# Processing Record 12 of Set 8 | sadovoye
# Processing Record 13 of Set 8 | bad wildungen
# Processing Record 14 of Set 8 | mango
# Processing Record 15 of Set 8 | ler
# Processing Record 16 of Set 8 | shimoda
# Processing Record 17 of Set 8 | talara
# Processing Record 18 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 8 | nanortalik
# Processing Record 20 of Set 8 | rostaq
# City not found. Skipping...
# Processing Record 21 of Set 8 | kirensk
# Processing Record 22 of Set 8 | whitehaven
# Processing Record 23 of Set 8 | dumai
# Processing Record 24 of Set 8 | ancud
# Processing Record 25 of Set 8 | nyahururu
# Processing Record 26 of Set 8 | hovd
# Processing Record 27 of Set 8 | ugoofaaru
# Processing Record 28 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 8 | ahipara
# Processing Record 30 of Set 8 | dunedin
# Processing Record 31 of Set 8 | jobner
# Processing Record 32 of Set 8 | lalibela
# Processing Record 33 of Set 8 | abu samrah
# Processing Record 34 of Set 8 | sao filipe
# Processing Record 35 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 36 of Set 8 | prata
# Processing Record 37 of Set 8 | pilar
# Processing Record 38 of Set 8 | kalavad
# Processing Record 39 of Set 8 | gordeyevka
# Processing Record 40 of Set 8 | hami
# Processing Record 41 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 8 | jacqueville
# Processing Record 43 of Set 8 | hazorasp
# Processing Record 44 of Set 8 | luderitz
# Processing Record 45 of Set 8 | saint anthony
# Processing Record 46 of Set 8 | kikwit
# Processing Record 47 of Set 8 | teya
# Processing Record 48 of Set 8 | nouadhibou
# Processing Record 49 of Set 8 | karabuk
# Processing Record 50 of Set 8 | palana
# Processing Record 1 of Set 9 | beaver dam
# Processing Record 2 of Set 9 | porto nacional
# Processing Record 3 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 4 of Set 9 | orel-izumrud
# Processing Record 5 of Set 9 | riyadh
# Processing Record 6 of Set 9 | yumen
# Processing Record 7 of Set 9 | saint-pierre
# Processing Record 8 of Set 9 | seoul
# Processing Record 9 of Set 9 | crowley
# Processing Record 10 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 11 of Set 9 | mocuba
# Processing Record 12 of Set 9 | puerto colombia
# Processing Record 13 of Set 9 | montevideo
# Processing Record 14 of Set 9 | naze
# Processing Record 15 of Set 9 | adrar
# Processing Record 16 of Set 9 | chifeng
# Processing Record 17 of Set 9 | mahina
# Processing Record 18 of Set 9 | marti
# Processing Record 19 of Set 9 | indiaroba
# Processing Record 20 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 21 of Set 9 | conde
# Processing Record 22 of Set 9 | pleshanovo
# Processing Record 23 of Set 9 | umm kaddadah
# Processing Record 24 of Set 9 | nikolsk
# Processing Record 25 of Set 9 | pangai
# Processing Record 26 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 9 | jeremie
# Processing Record 28 of Set 9 | homer
# Processing Record 29 of Set 9 | cambyreta
# City not found. Skipping...
# Processing Record 30 of Set 9 | ostrovnoy
# Processing Record 31 of Set 9 | ambilobe
# Processing Record 32 of Set 9 | cooma
# Processing Record 33 of Set 9 | daru
# Processing Record 34 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 9 | hwange
# Processing Record 36 of Set 9 | artyom
# Processing Record 37 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 38 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 39 of Set 9 | itarema
# Processing Record 40 of Set 9 | college
# Processing Record 41 of Set 9 | fortuna
# Processing Record 42 of Set 9 | dovolnoye
# Processing Record 43 of Set 9 | hailin
# Processing Record 44 of Set 9 | itoman
# Processing Record 45 of Set 9 | sur
# Processing Record 46 of Set 9 | kedrovyy
# Processing Record 47 of Set 9 | neijiang
# Processing Record 48 of Set 9 | aksu
# Processing Record 49 of Set 9 | kupang
# Processing Record 50 of Set 9 | dennery
# Processing Record 1 of Set 10 | port-gentil
# Processing Record 2 of Set 10 | acarau
# Processing Record 3 of Set 10 | shchuchye
# City not found. Skipping...
# Processing Record 4 of Set 10 | vestmanna
# Processing Record 5 of Set 10 | forio
# Processing Record 6 of Set 10 | lorengau
# Processing Record 7 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 8 of Set 10 | apache junction
# Processing Record 9 of Set 10 | san cristobal
# Processing Record 10 of Set 10 | beloha
# Processing Record 11 of Set 10 | pinawa
# Processing Record 12 of Set 10 | schkeuditz
# Processing Record 13 of Set 10 | bilibino
# Processing Record 14 of Set 10 | diego de almagro
# Processing Record 15 of Set 10 | russell
# Processing Record 16 of Set 10 | half moon bay
# Processing Record 17 of Set 10 | mikhaylovka
# Processing Record 18 of Set 10 | salalah
# Processing Record 19 of Set 10 | cochrane
# Processing Record 20 of Set 10 | nauta
# Processing Record 21 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 10 | poum
# Processing Record 23 of Set 10 | novouzensk
# Processing Record 24 of Set 10 | zyryanka
# Processing Record 25 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 10 | haines junction
# Processing Record 27 of Set 10 | tambopata
# Processing Record 28 of Set 10 | egvekinot
# Processing Record 29 of Set 10 | ilhabela
# Processing Record 30 of Set 10 | warmbad
# Processing Record 31 of Set 10 | sumbawanga
# Processing Record 32 of Set 10 | smithers
# Processing Record 33 of Set 10 | cocal
# Processing Record 34 of Set 10 | kloulklubed
# Processing Record 35 of Set 10 | verkhoyansk
# Processing Record 36 of Set 10 | abu kamal
# Processing Record 37 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 38 of Set 10 | sergiyev posad
# Processing Record 39 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 40 of Set 10 | hobyo
# Processing Record 41 of Set 10 | la rioja
# Processing Record 42 of Set 10 | tombouctou
# Processing Record 43 of Set 10 | phan thiet
# Processing Record 44 of Set 10 | berlevag
# Processing Record 45 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 10 | jinchang
# Processing Record 47 of Set 10 | guerrero negro
# Processing Record 48 of Set 10 | parkersburg
# Processing Record 49 of Set 10 | ambulu
# Processing Record 50 of Set 10 | ueno
# Processing Record 1 of Set 11 | meadow lake
# Processing Record 2 of Set 11 | hanna
# Processing Record 3 of Set 11 | great bend
# Processing Record 4 of Set 11 | moose factory
# Processing Record 5 of Set 11 | northam
# Processing Record 6 of Set 11 | lata
# Processing Record 7 of Set 11 | gonzalez
# Processing Record 8 of Set 11 | tongliao
# Processing Record 9 of Set 11 | svetlogorsk
# Processing Record 10 of Set 11 | ulaangom
# Processing Record 11 of Set 11 | baruun-urt
# Processing Record 12 of Set 11 | aklavik
# Processing Record 13 of Set 11 | cairns
# Processing Record 14 of Set 11 | doha
# Processing Record 15 of Set 11 | pandan
# Processing Record 16 of Set 11 | balikpapan
# Processing Record 17 of Set 11 | grindavik
# Processing Record 18 of Set 11 | alanya
# Processing Record 19 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 11 | hofn
# Processing Record 21 of Set 11 | hualmay
# Processing Record 22 of Set 11 | flinders
# Processing Record 23 of Set 11 | wajima
# Processing Record 24 of Set 11 | mandera
# Processing Record 25 of Set 11 | richards bay
# Processing Record 26 of Set 11 | orda
# Processing Record 27 of Set 11 | sulangan
# Processing Record 28 of Set 11 | pyinmana
# Processing Record 29 of Set 11 | shizunai
# Processing Record 30 of Set 11 | xining
# Processing Record 31 of Set 11 | dukat
# Processing Record 32 of Set 11 | tecpan
# Processing Record 33 of Set 11 | kaniama
# Processing Record 34 of Set 11 | san policarpo
# Processing Record 35 of Set 11 | dir
# Processing Record 36 of Set 11 | bahir dar
# Processing Record 37 of Set 11 | sydney
# Processing Record 38 of Set 11 | lexington
# Processing Record 39 of Set 11 | buala
# Processing Record 40 of Set 11 | hot springs
# Processing Record 41 of Set 11 | ondjiva
# Processing Record 42 of Set 11 | vreed en hoop
# City not found. Skipping...
# Processing Record 43 of Set 11 | portel
# Processing Record 44 of Set 11 | macedo de cavaleiros
# Processing Record 45 of Set 11 | bryukhovetskaya
# Processing Record 46 of Set 11 | port hardy
# Processing Record 47 of Set 11 | sambava
# Processing Record 48 of Set 11 | naberera
# Processing Record 49 of Set 11 | lamar
# Processing Record 50 of Set 11 | mayahi
# Processing Record 1 of Set 12 | saint-michel-des-saints
# Processing Record 2 of Set 12 | jalu
# Processing Record 3 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 4 of Set 12 | port macquarie
# Processing Record 5 of Set 12 | mackay
# Processing Record 6 of Set 12 | praia da vitoria
# Processing Record 7 of Set 12 | nikolskoye
# Processing Record 8 of Set 12 | garissa
# Processing Record 9 of Set 12 | bayangol
# Processing Record 10 of Set 12 | henties bay
# Processing Record 11 of Set 12 | bereda
# Processing Record 12 of Set 12 | samborondon
# Processing Record 13 of Set 12 | bani
# Processing Record 14 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 12 | vallenar
# Processing Record 16 of Set 12 | novopokrovka
# Processing Record 17 of Set 12 | katsina
# Processing Record 18 of Set 12 | vao
# Processing Record 19 of Set 12 | boa vista
# Processing Record 20 of Set 12 | martapura
# Processing Record 21 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 22 of Set 12 | puerto quijarro
# Processing Record 23 of Set 12 | virginia beach
# Processing Record 24 of Set 12 | lermontovka
# Processing Record 25 of Set 12 | mount gambier
# Processing Record 26 of Set 12 | manzanillo
# Processing Record 27 of Set 12 | sabzevar
# Processing Record 28 of Set 12 | igarka
# Processing Record 29 of Set 12 | west wendover
# Processing Record 30 of Set 12 | ville-marie
# Processing Record 31 of Set 12 | songea
# Processing Record 32 of Set 12 | makinsk
# Processing Record 33 of Set 12 | kisangani
# Processing Record 34 of Set 12 | verkhnevilyuysk
# Processing Record 35 of Set 12 | port hedland
# Processing Record 36 of Set 12 | aden
# Processing Record 37 of Set 12 | teguldet
# Processing Record 38 of Set 12 | maiduguri
# Processing Record 39 of Set 12 | kamenka
# Processing Record 40 of Set 12 | marseille
# Processing Record 41 of Set 12 | tigil
# Processing Record 42 of Set 12 | brewster
# Processing Record 43 of Set 12 | kangaatsiaq
# Processing Record 44 of Set 12 | wajir
# Processing Record 45 of Set 12 | sao joao da barra
# Processing Record 46 of Set 12 | hay river
# Processing Record 47 of Set 12 | lyubymivka
# Processing Record 48 of Set 12 | fuerte olimpo
# Processing Record 49 of Set 12 | ola
# Processing Record 50 of Set 12 | gojra
# Processing Record 1 of Set 13 | shyroke
# Processing Record 2 of Set 13 | rocha
# Processing Record 3 of Set 13 | sibolga
# Processing Record 4 of Set 13 | rio gallegos
# Processing Record 5 of Set 13 | payo
# Processing Record 6 of Set 13 | severobaykalsk
# Processing Record 7 of Set 13 | bathsheba
# Processing Record 8 of Set 13 | champerico
# Processing Record 9 of Set 13 | najran
# Processing Record 10 of Set 13 | luanda
# Processing Record 11 of Set 13 | leshukonskoye
# Processing Record 12 of Set 13 | codrington
# Processing Record 13 of Set 13 | hakui
# Processing Record 14 of Set 13 | ascension
# Processing Record 15 of Set 13 | chhapra
# Processing Record 16 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 17 of Set 13 | mana
# Processing Record 18 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 19 of Set 13 | nikel
# Processing Record 20 of Set 13 | orlik
# Processing Record 21 of Set 13 | duldurga
# Processing Record 22 of Set 13 | hvolsvollur
# Processing Record 23 of Set 13 | kamphaeng phet
# Processing Record 24 of Set 13 | birjand
# Processing Record 25 of Set 13 | shache
# Processing Record 26 of Set 13 | alghero
# Processing Record 27 of Set 13 | hue
# Processing Record 28 of Set 13 | trinidad
# Processing Record 29 of Set 13 | whitianga
# Processing Record 30 of Set 13 | matara
# Processing Record 31 of Set 13 | shenzhen
# Processing Record 32 of Set 13 | sungaipenuh
# Processing Record 33 of Set 13 | parkes
# Processing Record 34 of Set 13 | kenora
# Processing Record 35 of Set 13 | alpena
# Processing Record 36 of Set 13 | roald
# Processing Record 37 of Set 13 | ambovombe
# Processing Record 38 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 13 | batemans bay
# Processing Record 40 of Set 13 | leh
# Processing Record 41 of Set 13 | steamboat springs
# Processing Record 42 of Set 13 | namatanai
# Processing Record 43 of Set 13 | kiunga
# Processing Record 44 of Set 13 | sangar
# Processing Record 45 of Set 13 | vostok
# Processing Record 46 of Set 13 | maltahohe
# Processing Record 47 of Set 13 | nanchong
# Processing Record 48 of Set 13 | sawtell
# Processing Record 49 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 50 of Set 13 | zhizdra
# Processing Record 1 of Set 14 | karoi
# Processing Record 2 of Set 14 | shitanjing
# Processing Record 3 of Set 14 | kamina
# Processing Record 4 of Set 14 | tornio
# Processing Record 5 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 14 | abu road
# Processing Record 7 of Set 14 | muisne
# Processing Record 8 of Set 14 | alta floresta
# Processing Record 9 of Set 14 | algiers
# Processing Record 10 of Set 14 | nago
# Processing Record 11 of Set 14 | piranshahr
# Processing Record 12 of Set 14 | nchelenge
# Processing Record 13 of Set 14 | batagay
# Processing Record 14 of Set 14 | gornopravdinsk
# Processing Record 15 of Set 14 | alugan
# Processing Record 16 of Set 14 | grand-lahou
# Processing Record 17 of Set 14 | vila do maio
# Processing Record 18 of Set 14 | belyy yar
# Processing Record 19 of Set 14 | tuy hoa
# Processing Record 20 of Set 14 | selje
# Processing Record 21 of Set 14 | turukhansk
# Processing Record 22 of Set 14 | zhob
# Processing Record 23 of Set 14 | vicuna
# Processing Record 24 of Set 14 | college station
# Processing Record 25 of Set 14 | ngorongoro
# Processing Record 26 of Set 14 | kysyl-syr
# Processing Record 27 of Set 14 | beneditinos
# Processing Record 28 of Set 14 | mushie
# Processing Record 29 of Set 14 | hinatuan
# Processing Record 30 of Set 14 | mecca
# Processing Record 31 of Set 14 | uglekamensk
# Processing Record 32 of Set 14 | palimbang
# Processing Record 33 of Set 14 | margate
# Processing Record 34 of Set 14 | alibog
# City not found. Skipping...
# Processing Record 35 of Set 14 | kailua
# Processing Record 36 of Set 14 | zhangye
# Processing Record 37 of Set 14 | anchorage
# Processing Record 38 of Set 14 | lavrentiya
# Processing Record 39 of Set 14 | nakhon thai
# Processing Record 40 of Set 14 | foz
# Processing Record 41 of Set 14 | corner brook
# Processing Record 42 of Set 14 | ha tinh
# Processing Record 43 of Set 14 | oron
# Processing Record 44 of Set 14 | taoudenni
# Processing Record 45 of Set 14 | erzin
# Processing Record 46 of Set 14 | los llanos de aridane
# Processing Record 47 of Set 14 | qaqortoq
# Processing Record 48 of Set 14 | koboldo
# City not found. Skipping...
# Processing Record 49 of Set 14 | christchurch
# Processing Record 50 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 1 of Set 15 | forrest city
# Processing Record 2 of Set 15 | muros
# Processing Record 3 of Set 15 | torres
# Processing Record 4 of Set 15 | collierville
# Processing Record 5 of Set 15 | suluq
# Processing Record 6 of Set 15 | pangnirtung
# Processing Record 7 of Set 15 | kashi
# Processing Record 8 of Set 15 | ures
# Processing Record 9 of Set 15 | tateyama
# Processing Record 10 of Set 15 | merrill
# Processing Record 11 of Set 15 | dutlwe
# Processing Record 12 of Set 15 | bejar
# Processing Record 13 of Set 15 | supe
# Processing Record 14 of Set 15 | praya
# Processing Record 15 of Set 15 | sisimiut
# Processing Record 16 of Set 15 | garachine
# Processing Record 17 of Set 15 | tarko-sale
# Processing Record 18 of Set 15 | tartki
# City not found. Skipping...
# Processing Record 19 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 20 of Set 15 | redding
# Processing Record 21 of Set 15 | cururupu
# Processing Record 22 of Set 15 | angoche
# Processing Record 23 of Set 15 | juneau
# Processing Record 24 of Set 15 | loiza
# Processing Record 25 of Set 15 | nadym
# Processing Record 26 of Set 15 | turbat
# Processing Record 27 of Set 15 | talnakh
# Processing Record 28 of Set 15 | luwuk
# Processing Record 29 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 30 of Set 15 | fukue
# Processing Record 31 of Set 15 | xichang
# Processing Record 32 of Set 15 | mavrovi anovi
# Processing Record 33 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 34 of Set 15 | teknaf
# Processing Record 35 of Set 15 | mbigou
# Processing Record 36 of Set 15 | sumbe
# Processing Record 37 of Set 15 | lubao
# Processing Record 38 of Set 15 | belebey
# Processing Record 39 of Set 15 | ocean city
# Processing Record 40 of Set 15 | okitipupa
# Processing Record 41 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 15 | selma
# Processing Record 43 of Set 15 | yarada
# Processing Record 44 of Set 15 | strathmore
# Processing Record 45 of Set 15 | roebourne
# Processing Record 46 of Set 15 | petatlan
# Processing Record 47 of Set 15 | jablah
# Processing Record 48 of Set 15 | kilindoni
# Processing Record 49 of Set 15 | gat
# Processing Record 50 of Set 15 | porto walter
# Processing Record 1 of Set 16 | hawick
# Processing Record 2 of Set 16 | salinopolis
# Processing Record 3 of Set 16 | lulea
# Processing Record 4 of Set 16 | san carlos de bariloche
# Processing Record 5 of Set 16 | kungurtug
# Processing Record 6 of Set 16 | matagami
# Processing Record 7 of Set 16 | shihezi
# Processing Record 8 of Set 16 | puerto carreno
# Processing Record 9 of Set 16 | guiong
# Processing Record 10 of Set 16 | elizabeth city
# Processing Record 11 of Set 16 | maniitsoq
# Processing Record 12 of Set 16 | buon me thuot
# City not found. Skipping...
# Processing Record 13 of Set 16 | cockburn harbour
# City not found. Skipping...
# Processing Record 14 of Set 16 | paamiut
# Processing Record 15 of Set 16 | karpathos
# Processing Record 16 of Set 16 | sayyan
# Processing Record 17 of Set 16 | yar-sale
# Processing Record 18 of Set 16 | ilulissat
# Processing Record 19 of Set 16 | bedong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
# convert list of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0              Tasiilaq      GL  65.6145  -37.6368     32.16        95
# 1             Upernavik      GL  72.7868  -56.1549     16.59        67
# 2               Ushuaia      AR -54.8000  -68.3000     33.46        80
# 3  Vila Franca Do Campo      PT  37.7167  -25.4333     66.61        74
# 4                  Lebu      CL -37.6167  -73.6500     57.76        77
# 5                Hobart      AU -42.8794  147.3294     48.06        76
# 6                 Bluff      NZ -46.6000  168.3333     52.34        92
# 7                Barrow      US  71.2906 -156.7887     28.42        80
# 8                  Tual      ID  -5.6667  132.7500     81.32        78
# 9               Markova      UA  48.6758   24.4138     33.98        80
#
#    Cloudiness  Wind Speed Current Description
# 0         100       22.55                snow
# 1          98        8.30     overcast clouds
# 2          75       39.12                snow
# 3           0        6.24           clear sky
# 4           9       10.33           clear sky
# 5          75        1.01       broken clouds
# 6          84        5.12       broken clouds
# 7          90        5.75     overcast clouds
# 8          95        3.20       moderate rain
# 9          50        4.41    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
