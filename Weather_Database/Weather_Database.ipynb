# %%
# Import the dependencies.
from citipy import citipy
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 758

# %%
# Import the request library.
import requests

from datetime import datetime
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # Adding Weather description
        weather_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | norman wells
# Processing Record 2 of Set 1 | taltal
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | karasjok
# Processing Record 5 of Set 1 | waingapu
# Processing Record 6 of Set 1 | vardo
# Processing Record 7 of Set 1 | vila franca do campo
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | port lincoln
# Processing Record 10 of Set 1 | sechura
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | guerrero negro
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | soyo
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | lazarev
# Processing Record 20 of Set 1 | savannah bight
# Processing Record 21 of Set 1 | chokurdakh
# Processing Record 22 of Set 1 | klaipeda
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | shush
# Processing Record 25 of Set 1 | hithadhoo
# Processing Record 26 of Set 1 | cabo san lucas
# Processing Record 27 of Set 1 | grand gaube
# Processing Record 28 of Set 1 | dhaka
# Processing Record 29 of Set 1 | coquimbo
# Processing Record 30 of Set 1 | tuatapere
# Processing Record 31 of Set 1 | correntina
# Processing Record 32 of Set 1 | upernavik
# Processing Record 33 of Set 1 | bengkulu
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | kavieng
# Processing Record 37 of Set 1 | progreso
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | luganville
# Processing Record 41 of Set 1 | marsa matruh
# Processing Record 42 of Set 1 | harper
# Processing Record 43 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | bandarbeyla
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | ambon
# Processing Record 48 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | denpasar
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | esperance
# Processing Record 9 of Set 2 | comodoro rivadavia
# Processing Record 10 of Set 2 | ritchie
# Processing Record 11 of Set 2 | synya
# Processing Record 12 of Set 2 | camocim
# Processing Record 13 of Set 2 | anamur
# Processing Record 14 of Set 2 | sabzevar
# Processing Record 15 of Set 2 | sezana
# Processing Record 16 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 2 | talnakh
# Processing Record 18 of Set 2 | durg
# Processing Record 19 of Set 2 | pisco
# Processing Record 20 of Set 2 | codrington
# Processing Record 21 of Set 2 | shirgaon
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | east london
# Processing Record 24 of Set 2 | burayevo
# Processing Record 25 of Set 2 | longyearbyen
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | khatanga
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | peterhead
# Processing Record 30 of Set 2 | ribeira grande
# Processing Record 31 of Set 2 | ketchikan
# Processing Record 32 of Set 2 | jalu
# Processing Record 33 of Set 2 | palmer
# Processing Record 34 of Set 2 | bani walid
# Processing Record 35 of Set 2 | svetlyy
# Processing Record 36 of Set 2 | rorvik
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | poum
# Processing Record 39 of Set 2 | tiksi
# Processing Record 40 of Set 2 | humaita
# Processing Record 41 of Set 2 | faya
# Processing Record 42 of Set 2 | mount gambier
# Processing Record 43 of Set 2 | urbano santos
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | seymchan
# Processing Record 46 of Set 2 | constantine
# Processing Record 47 of Set 2 | pentecoste
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | carlsbad
# Processing Record 1 of Set 3 | abu samrah
# Processing Record 2 of Set 3 | hokitika
# Processing Record 3 of Set 3 | urumqi
# Processing Record 4 of Set 3 | pangnirtung
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | egvekinot
# Processing Record 7 of Set 3 | razlog
# Processing Record 8 of Set 3 | thompson
# Processing Record 9 of Set 3 | port-gentil
# Processing Record 10 of Set 3 | lazaro cardenas
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | bairnsdale
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | shingu
# Processing Record 15 of Set 3 | terpinnya
# Processing Record 16 of Set 3 | mar del plata
# Processing Record 17 of Set 3 | bilibino
# Processing Record 18 of Set 3 | mercedes
# Processing Record 19 of Set 3 | quetta
# Processing Record 20 of Set 3 | butaritari
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 3 | rocha
# Processing Record 24 of Set 3 | kichera
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | mamallapuram
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | la palma
# Processing Record 29 of Set 3 | petatlan
# Processing Record 30 of Set 3 | lasa
# Processing Record 31 of Set 3 | nikolskoye
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | marsh harbour
# Processing Record 34 of Set 3 | sao filipe
# Processing Record 35 of Set 3 | jardim
# Processing Record 36 of Set 3 | quelimane
# Processing Record 37 of Set 3 | chapais
# Processing Record 38 of Set 3 | harindanga
# Processing Record 39 of Set 3 | korla
# Processing Record 40 of Set 3 | college
# Processing Record 41 of Set 3 | kahului
# Processing Record 42 of Set 3 | punta arenas
# Processing Record 43 of Set 3 | kshenskiy
# Processing Record 44 of Set 3 | celestun
# Processing Record 45 of Set 3 | vendome
# Processing Record 46 of Set 3 | saint-augustin
# Processing Record 47 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 3 | alcudia
# Processing Record 49 of Set 3 | broken hill
# Processing Record 50 of Set 3 | itabira
# Processing Record 1 of Set 4 | kibala
# Processing Record 2 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 4 | komsomolskiy
# Processing Record 4 of Set 4 | aykhal
# Processing Record 5 of Set 4 | urucui
# Processing Record 6 of Set 4 | bethel
# Processing Record 7 of Set 4 | soeng sang
# Processing Record 8 of Set 4 | limanu
# Processing Record 9 of Set 4 | tukrah
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 4 | new norfolk
# Processing Record 14 of Set 4 | bredasdorp
# Processing Record 15 of Set 4 | hofn
# Processing Record 16 of Set 4 | darhan
# Processing Record 17 of Set 4 | carutapera
# Processing Record 18 of Set 4 | teya
# Processing Record 19 of Set 4 | mosta
# Processing Record 20 of Set 4 | burica
# City not found. Skipping...
# Processing Record 21 of Set 4 | myitkyina
# Processing Record 22 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 4 | hermanus
# Processing Record 24 of Set 4 | saint-francois
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | cap malheureux
# Processing Record 27 of Set 4 | vargashi
# Processing Record 28 of Set 4 | gulshat
# City not found. Skipping...
# Processing Record 29 of Set 4 | mandalgovi
# Processing Record 30 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 4 | katsuura
# Processing Record 32 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 4 | rafai
# Processing Record 34 of Set 4 | dudinka
# Processing Record 35 of Set 4 | filingue
# Processing Record 36 of Set 4 | canchungo
# Processing Record 37 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 4 | dikson
# Processing Record 39 of Set 4 | vestmannaeyjar
# Processing Record 40 of Set 4 | kungurtug
# Processing Record 41 of Set 4 | beira
# Processing Record 42 of Set 4 | kirensk
# Processing Record 43 of Set 4 | shorapur
# Processing Record 44 of Set 4 | natitingou
# Processing Record 45 of Set 4 | bambous virieux
# Processing Record 46 of Set 4 | siocon
# Processing Record 47 of Set 4 | saskylakh
# Processing Record 48 of Set 4 | saint george
# Processing Record 49 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 4 | mudyuga
# City not found. Skipping...
# Processing Record 1 of Set 5 | clyde river
# Processing Record 2 of Set 5 | yeppoon
# Processing Record 3 of Set 5 | souillac
# Processing Record 4 of Set 5 | dulce grande
# Processing Record 5 of Set 5 | manokwari
# Processing Record 6 of Set 5 | coihueco
# Processing Record 7 of Set 5 | grindavik
# Processing Record 8 of Set 5 | goure
# Processing Record 9 of Set 5 | umm lajj
# Processing Record 10 of Set 5 | hami
# Processing Record 11 of Set 5 | nuristan
# Processing Record 12 of Set 5 | huntingdon
# Processing Record 13 of Set 5 | wahiawa
# Processing Record 14 of Set 5 | sharan
# Processing Record 15 of Set 5 | udachnyy
# Processing Record 16 of Set 5 | georgetown
# Processing Record 17 of Set 5 | buraydah
# Processing Record 18 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 5 | kaniama
# Processing Record 20 of Set 5 | springbok
# Processing Record 21 of Set 5 | itarema
# Processing Record 22 of Set 5 | kommunar
# Processing Record 23 of Set 5 | caravelas
# Processing Record 24 of Set 5 | dingle
# Processing Record 25 of Set 5 | camacha
# Processing Record 26 of Set 5 | arraial do cabo
# Processing Record 27 of Set 5 | hualmay
# Processing Record 28 of Set 5 | saint anthony
# Processing Record 29 of Set 5 | katobu
# Processing Record 30 of Set 5 | laminusa
# Processing Record 31 of Set 5 | smoky lake
# Processing Record 32 of Set 5 | zhumadian
# Processing Record 33 of Set 5 | ituni
# City not found. Skipping...
# Processing Record 34 of Set 5 | hirara
# Processing Record 35 of Set 5 | chernaya kholunitsa
# Processing Record 36 of Set 5 | rio gallegos
# Processing Record 37 of Set 5 | sisimiut
# Processing Record 38 of Set 5 | escanaba
# Processing Record 39 of Set 5 | padang
# Processing Record 40 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 5 | lahij
# Processing Record 42 of Set 5 | mehamn
# Processing Record 43 of Set 5 | borskoye
# Processing Record 44 of Set 5 | smithers
# Processing Record 45 of Set 5 | barrow
# Processing Record 46 of Set 5 | iqaluit
# Processing Record 47 of Set 5 | alvorada
# Processing Record 48 of Set 5 | kruisfontein
# Processing Record 49 of Set 5 | faanui
# Processing Record 50 of Set 5 | eskasem
# City not found. Skipping...
# Processing Record 1 of Set 6 | mardin
# Processing Record 2 of Set 6 | nobres
# Processing Record 3 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 6 | mayumba
# Processing Record 5 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 6 | kamenka
# Processing Record 7 of Set 6 | watsa
# Processing Record 8 of Set 6 | lompoc
# Processing Record 9 of Set 6 | touros
# Processing Record 10 of Set 6 | sahiwal
# Processing Record 11 of Set 6 | fereydunshahr
# Processing Record 12 of Set 6 | simpang
# Processing Record 13 of Set 6 | vila velha
# Processing Record 14 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 6 | maarianhamina
# Processing Record 16 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 17 of Set 6 | mopti
# Processing Record 18 of Set 6 | provideniya
# Processing Record 19 of Set 6 | rancaekek
# City not found. Skipping...
# Processing Record 20 of Set 6 | lock haven
# Processing Record 21 of Set 6 | yebaishou
# Processing Record 22 of Set 6 | feijo
# Processing Record 23 of Set 6 | velsk
# Processing Record 24 of Set 6 | hobyo
# Processing Record 25 of Set 6 | zheleznodorozhnyy
# Processing Record 26 of Set 6 | severo-kurilsk
# Processing Record 27 of Set 6 | sur
# Processing Record 28 of Set 6 | kapiri mposhi
# Processing Record 29 of Set 6 | toowoomba
# Processing Record 30 of Set 6 | nouadhibou
# Processing Record 31 of Set 6 | leningradskiy
# Processing Record 32 of Set 6 | safaga
# Processing Record 33 of Set 6 | ternate
# Processing Record 34 of Set 6 | kautokeino
# Processing Record 35 of Set 6 | kroya
# Processing Record 36 of Set 6 | airai
# Processing Record 37 of Set 6 | usinsk
# Processing Record 38 of Set 6 | opuwo
# Processing Record 39 of Set 6 | azpeitia
# Processing Record 40 of Set 6 | mandurah
# Processing Record 41 of Set 6 | akyab
# Processing Record 42 of Set 6 | nuevitas
# Processing Record 43 of Set 6 | cayenne
# Processing Record 44 of Set 6 | muzhi
# Processing Record 45 of Set 6 | yaring
# Processing Record 46 of Set 6 | deputatskiy
# Processing Record 47 of Set 6 | kualakapuas
# Processing Record 48 of Set 6 | gizo
# Processing Record 49 of Set 6 | shihezi
# Processing Record 50 of Set 6 | ahipara
# Processing Record 1 of Set 7 | sakaiminato
# Processing Record 2 of Set 7 | te anau
# Processing Record 3 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 7 | puteyets
# Processing Record 5 of Set 7 | inhambane
# Processing Record 6 of Set 7 | burkhala
# City not found. Skipping...
# Processing Record 7 of Set 7 | oparino
# Processing Record 8 of Set 7 | aksay
# Processing Record 9 of Set 7 | matsanga
# City not found. Skipping...
# Processing Record 10 of Set 7 | paamiut
# Processing Record 11 of Set 7 | batesville
# Processing Record 12 of Set 7 | muros
# Processing Record 13 of Set 7 | mount isa
# Processing Record 14 of Set 7 | rochegda
# Processing Record 15 of Set 7 | richards bay
# Processing Record 16 of Set 7 | chimbote
# Processing Record 17 of Set 7 | binga
# Processing Record 18 of Set 7 | chirongui
# Processing Record 19 of Set 7 | tamandare
# Processing Record 20 of Set 7 | tagusao
# Processing Record 21 of Set 7 | saint-pierre
# Processing Record 22 of Set 7 | grootfontein
# Processing Record 23 of Set 7 | sola
# Processing Record 24 of Set 7 | lagoa
# Processing Record 25 of Set 7 | kobojango
# City not found. Skipping...
# Processing Record 26 of Set 7 | kokopo
# Processing Record 27 of Set 7 | abha
# Processing Record 28 of Set 7 | coihaique
# Processing Record 29 of Set 7 | fairbanks
# Processing Record 30 of Set 7 | ksenyevka
# City not found. Skipping...
# Processing Record 31 of Set 7 | port hardy
# Processing Record 32 of Set 7 | port blair
# Processing Record 33 of Set 7 | obo
# Processing Record 34 of Set 7 | ipoh
# Processing Record 35 of Set 7 | tadine
# Processing Record 36 of Set 7 | nioro
# Processing Record 37 of Set 7 | san jose
# Processing Record 38 of Set 7 | of
# City not found. Skipping...
# Processing Record 39 of Set 7 | culiacan
# Processing Record 40 of Set 7 | kazerun
# Processing Record 41 of Set 7 | fort collins
# Processing Record 42 of Set 7 | marstal
# Processing Record 43 of Set 7 | tilichiki
# Processing Record 44 of Set 7 | portland
# Processing Record 45 of Set 7 | yerbogachen
# Processing Record 46 of Set 7 | gat
# Processing Record 47 of Set 7 | san patricio
# Processing Record 48 of Set 7 | meadow lake
# Processing Record 49 of Set 7 | husavik
# Processing Record 50 of Set 7 | fortuna
# Processing Record 1 of Set 8 | lakhnadon
# Processing Record 2 of Set 8 | maua
# Processing Record 3 of Set 8 | batetskiy
# Processing Record 4 of Set 8 | abay
# Processing Record 5 of Set 8 | vikhorevka
# Processing Record 6 of Set 8 | baramati
# Processing Record 7 of Set 8 | catuday
# Processing Record 8 of Set 8 | mata
# Processing Record 9 of Set 8 | hovd
# Processing Record 10 of Set 8 | gazojak
# Processing Record 11 of Set 8 | ancud
# Processing Record 12 of Set 8 | camapua
# Processing Record 13 of Set 8 | kloulklubed
# Processing Record 14 of Set 8 | sulangan
# Processing Record 15 of Set 8 | olafsvik
# Processing Record 16 of Set 8 | haikou
# Processing Record 17 of Set 8 | okahandja
# Processing Record 18 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 8 | bubaque
# Processing Record 20 of Set 8 | iquique
# Processing Record 21 of Set 8 | geraldton
# Processing Record 22 of Set 8 | mackay
# Processing Record 23 of Set 8 | jinka
# Processing Record 24 of Set 8 | omsukchan
# Processing Record 25 of Set 8 | bonthe
# Processing Record 26 of Set 8 | brae
# Processing Record 27 of Set 8 | zaysan
# Processing Record 28 of Set 8 | vagur
# Processing Record 29 of Set 8 | matamoros
# Processing Record 30 of Set 8 | catia la mar
# Processing Record 31 of Set 8 | okhotsk
# Processing Record 32 of Set 8 | kaeo
# Processing Record 33 of Set 8 | yar-sale
# Processing Record 34 of Set 8 | chuy
# Processing Record 35 of Set 8 | portales
# Processing Record 36 of Set 8 | rundu
# Processing Record 37 of Set 8 | warrensburg
# Processing Record 38 of Set 8 | los llanos de aridane
# Processing Record 39 of Set 8 | naze
# Processing Record 40 of Set 8 | bereda
# Processing Record 41 of Set 8 | puerto escondido
# Processing Record 42 of Set 8 | altamont
# Processing Record 43 of Set 8 | isangel
# Processing Record 44 of Set 8 | hamilton
# Processing Record 45 of Set 8 | jamame
# Processing Record 46 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 47 of Set 8 | adrar
# Processing Record 48 of Set 8 | meulaboh
# Processing Record 49 of Set 8 | wasilla
# Processing Record 50 of Set 8 | kavaratti
# Processing Record 1 of Set 9 | palmares
# Processing Record 2 of Set 9 | chicama
# Processing Record 3 of Set 9 | saint-joseph
# Processing Record 4 of Set 9 | chik
# Processing Record 5 of Set 9 | pocone
# Processing Record 6 of Set 9 | ondangwa
# Processing Record 7 of Set 9 | pemangkat
# Processing Record 8 of Set 9 | green river
# Processing Record 9 of Set 9 | kenai
# Processing Record 10 of Set 9 | kaitangata
# Processing Record 11 of Set 9 | rawah
# Processing Record 12 of Set 9 | vargem alta
# Processing Record 13 of Set 9 | birzai
# Processing Record 14 of Set 9 | sao joao da barra
# Processing Record 15 of Set 9 | la ronge
# Processing Record 16 of Set 9 | belle fourche
# Processing Record 17 of Set 9 | kedougou
# Processing Record 18 of Set 9 | uglovskoye
# Processing Record 19 of Set 9 | bardiyah
# Processing Record 20 of Set 9 | soweto
# Processing Record 21 of Set 9 | rockhampton
# Processing Record 22 of Set 9 | esterhazy
# Processing Record 23 of Set 9 | nome
# Processing Record 24 of Set 9 | kalga
# Processing Record 25 of Set 9 | thongwa
# Processing Record 26 of Set 9 | berlevag
# Processing Record 27 of Set 9 | zverinogolovskoye
# Processing Record 28 of Set 9 | kirakira
# Processing Record 29 of Set 9 | mul
# Processing Record 30 of Set 9 | cockburn town
# Processing Record 31 of Set 9 | zeitz
# Processing Record 32 of Set 9 | port-cartier
# Processing Record 33 of Set 9 | lithgow
# Processing Record 34 of Set 9 | akonolinga
# Processing Record 35 of Set 9 | rudnogorsk
# Processing Record 36 of Set 9 | soc trang
# Processing Record 37 of Set 9 | asau
# Processing Record 38 of Set 9 | dordrecht
# Processing Record 39 of Set 9 | lavrentiya
# Processing Record 40 of Set 9 | fruitvale
# Processing Record 41 of Set 9 | buala
# Processing Record 42 of Set 9 | makat
# Processing Record 43 of Set 9 | paso de los toros
# Processing Record 44 of Set 9 | ahumada
# City not found. Skipping...
# Processing Record 45 of Set 9 | boa esperanca
# Processing Record 46 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 9 | bac lieu
# Processing Record 48 of Set 9 | simao
# Processing Record 49 of Set 9 | dalvik
# Processing Record 50 of Set 9 | listvyanskiy
# Processing Record 1 of Set 10 | whitehorse
# Processing Record 2 of Set 10 | gushikawa
# Processing Record 3 of Set 10 | carnarvon
# Processing Record 4 of Set 10 | sandovo
# Processing Record 5 of Set 10 | hambantota
# Processing Record 6 of Set 10 | amga
# Processing Record 7 of Set 10 | maningrida
# Processing Record 8 of Set 10 | ixtapa
# Processing Record 9 of Set 10 | malpura
# Processing Record 10 of Set 10 | leh
# Processing Record 11 of Set 10 | taoudenni
# Processing Record 12 of Set 10 | requena
# Processing Record 13 of Set 10 | kuching
# Processing Record 14 of Set 10 | livingston
# Processing Record 15 of Set 10 | boa vista
# Processing Record 16 of Set 10 | byron bay
# Processing Record 17 of Set 10 | todos santos
# Processing Record 18 of Set 10 | clarence town
# Processing Record 19 of Set 10 | vao
# Processing Record 20 of Set 10 | alofi
# Processing Record 21 of Set 10 | chikola
# Processing Record 22 of Set 10 | rebrikha
# Processing Record 23 of Set 10 | ulaangom
# Processing Record 24 of Set 10 | port augusta
# Processing Record 25 of Set 10 | morkovice-slizany
# City not found. Skipping...
# Processing Record 26 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 27 of Set 10 | rafaela
# Processing Record 28 of Set 10 | ostrovnoy
# Processing Record 29 of Set 10 | tazovskiy
# Processing Record 30 of Set 10 | nizwa
# Processing Record 31 of Set 10 | puerto armuelles
# Processing Record 32 of Set 10 | muisne
# Processing Record 33 of Set 10 | sorland
# Processing Record 34 of Set 10 | ornskoldsvik
# Processing Record 35 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 10 | acari
# Processing Record 37 of Set 10 | nyurba
# Processing Record 38 of Set 10 | manutuke
# Processing Record 39 of Set 10 | murray bridge
# Processing Record 40 of Set 10 | batemans bay
# Processing Record 41 of Set 10 | ngunguru
# Processing Record 42 of Set 10 | waipawa
# Processing Record 43 of Set 10 | salalah
# Processing Record 44 of Set 10 | pousat
# City not found. Skipping...
# Processing Record 45 of Set 10 | bathurst
# Processing Record 46 of Set 10 | aklavik
# Processing Record 47 of Set 10 | marivan
# Processing Record 48 of Set 10 | sitka
# Processing Record 49 of Set 10 | labuhan
# Processing Record 50 of Set 10 | novikovo
# Processing Record 1 of Set 11 | colares
# Processing Record 2 of Set 11 | tautira
# Processing Record 3 of Set 11 | gorontalo
# Processing Record 4 of Set 11 | shu
# Processing Record 5 of Set 11 | palmerston north
# Processing Record 6 of Set 11 | mazagao
# Processing Record 7 of Set 11 | milkovo
# Processing Record 8 of Set 11 | indiaroba
# Processing Record 9 of Set 11 | ishigaki
# Processing Record 10 of Set 11 | alta floresta
# Processing Record 11 of Set 11 | kaoma
# Processing Record 12 of Set 11 | arawa
# Processing Record 13 of Set 11 | wanning
# Processing Record 14 of Set 11 | zitlala
# Processing Record 15 of Set 11 | ipixuna
# Processing Record 16 of Set 11 | sirtich
# Processing Record 17 of Set 11 | vianopolis
# Processing Record 18 of Set 11 | kyaiklat
# Processing Record 19 of Set 11 | sistranda
# Processing Record 20 of Set 11 | dolores
# Processing Record 21 of Set 11 | srednekolymsk
# Processing Record 22 of Set 11 | thinadhoo
# Processing Record 23 of Set 11 | aksu
# Processing Record 24 of Set 11 | laguna
# Processing Record 25 of Set 11 | bay roberts
# Processing Record 26 of Set 11 | san quintin
# Processing Record 27 of Set 11 | nishihara
# Processing Record 28 of Set 11 | saint-georges
# Processing Record 29 of Set 11 | tessalit
# Processing Record 30 of Set 11 | tawau
# Processing Record 31 of Set 11 | lamu
# Processing Record 32 of Set 11 | corinto
# Processing Record 33 of Set 11 | taunusstein
# Processing Record 34 of Set 11 | conway
# Processing Record 35 of Set 11 | sao cristovao
# Processing Record 36 of Set 11 | usogorsk
# Processing Record 37 of Set 11 | yafran
# Processing Record 38 of Set 11 | kitwe
# Processing Record 39 of Set 11 | kargat
# Processing Record 40 of Set 11 | biak
# Processing Record 41 of Set 11 | saint-michel-des-saints
# Processing Record 42 of Set 11 | zhigansk
# Processing Record 43 of Set 11 | ararangua
# Processing Record 44 of Set 11 | norcasia
# Processing Record 45 of Set 11 | fort walton beach
# Processing Record 46 of Set 11 | mudanya
# Processing Record 47 of Set 11 | kailua
# Processing Record 48 of Set 11 | marawi
# Processing Record 49 of Set 11 | rudsar
# Processing Record 50 of Set 11 | turukhansk
# Processing Record 1 of Set 12 | jammu
# Processing Record 2 of Set 12 | maracaibo
# Processing Record 3 of Set 12 | meerzorg
# City not found. Skipping...
# Processing Record 4 of Set 12 | timmins
# Processing Record 5 of Set 12 | avila
# Processing Record 6 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 7 of Set 12 | atbasar
# Processing Record 8 of Set 12 | oktyabrskoye
# Processing Record 9 of Set 12 | auki
# Processing Record 10 of Set 12 | margate
# Processing Record 11 of Set 12 | sadao
# Processing Record 12 of Set 12 | araouane
# Processing Record 13 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 14 of Set 12 | luanda
# Processing Record 15 of Set 12 | maniitsoq
# Processing Record 16 of Set 12 | malyn
# Processing Record 17 of Set 12 | lorengau
# Processing Record 18 of Set 12 | la ligua
# Processing Record 19 of Set 12 | haimen
# Processing Record 20 of Set 12 | rudnyy
# Processing Record 21 of Set 12 | lulea
# Processing Record 22 of Set 12 | ushtobe
# Processing Record 23 of Set 12 | qasigiannguit
# Processing Record 24 of Set 12 | kachug
# Processing Record 25 of Set 12 | henties bay
# Processing Record 26 of Set 12 | beloha
# Processing Record 27 of Set 12 | jinchang
# Processing Record 28 of Set 12 | fort-shevchenko
# Processing Record 29 of Set 12 | carndonagh
# Processing Record 30 of Set 12 | havre-saint-pierre
# Processing Record 31 of Set 12 | maloshuyka
# City not found. Skipping...
# Processing Record 32 of Set 12 | sivaki
# Processing Record 33 of Set 12 | tougan
# Processing Record 34 of Set 12 | narsaq
# Processing Record 35 of Set 12 | belmonte
# Processing Record 36 of Set 12 | mwinilunga
# Processing Record 37 of Set 12 | kudahuvadhoo
# Processing Record 38 of Set 12 | santa maria
# Processing Record 39 of Set 12 | contamana
# Processing Record 40 of Set 12 | north bend
# Processing Record 41 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 42 of Set 12 | marrakesh
# Processing Record 43 of Set 12 | pundaguitan
# Processing Record 44 of Set 12 | beni mazar
# Processing Record 45 of Set 12 | baculin
# Processing Record 46 of Set 12 | segou
# Processing Record 47 of Set 12 | hammerfest
# Processing Record 48 of Set 12 | vaxjo
# Processing Record 49 of Set 12 | kutum
# Processing Record 50 of Set 12 | vilyuysk
# Processing Record 1 of Set 13 | ankazoabo
# Processing Record 2 of Set 13 | acajutla
# Processing Record 3 of Set 13 | moerai
# Processing Record 4 of Set 13 | mahon
# Processing Record 5 of Set 13 | chunoyar
# Processing Record 6 of Set 13 | rivadavia
# Processing Record 7 of Set 13 | dong hoi
# Processing Record 8 of Set 13 | palana
# Processing Record 9 of Set 13 | san cristobal
# Processing Record 10 of Set 13 | ponta delgada
# Processing Record 11 of Set 13 | boguchany
# Processing Record 12 of Set 13 | canelones
# Processing Record 13 of Set 13 | constitucion
# Processing Record 14 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 15 of Set 13 | honningsvag
# Processing Record 16 of Set 13 | kurilsk
# Processing Record 17 of Set 13 | heihe
# Processing Record 18 of Set 13 | kilifi
# Processing Record 19 of Set 13 | karratha
# Processing Record 20 of Set 13 | moctezuma
# Processing Record 21 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 22 of Set 13 | thabazimbi
# Processing Record 23 of Set 13 | springdale
# Processing Record 24 of Set 13 | neiafu
# Processing Record 25 of Set 13 | krasnoselkup
# Processing Record 26 of Set 13 | rawlins
# Processing Record 27 of Set 13 | svetlogorsk
# Processing Record 28 of Set 13 | arvika
# Processing Record 29 of Set 13 | rauma
# Processing Record 30 of Set 13 | skjervoy
# Processing Record 31 of Set 13 | port macquarie
# Processing Record 32 of Set 13 | ascension
# Processing Record 33 of Set 13 | hay river
# Processing Record 34 of Set 13 | kindu
# Processing Record 35 of Set 13 | tecoanapa
# Processing Record 36 of Set 13 | agen
# Processing Record 37 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 38 of Set 13 | hohhot
# Processing Record 39 of Set 13 | bagotville
# Processing Record 40 of Set 13 | kurumkan
# Processing Record 41 of Set 13 | nueve de julio
# Processing Record 42 of Set 13 | orlik
# Processing Record 43 of Set 13 | havelock
# Processing Record 44 of Set 13 | yantal
# Processing Record 45 of Set 13 | paciran
# Processing Record 46 of Set 13 | porto novo
# Processing Record 47 of Set 13 | dunedin
# Processing Record 48 of Set 13 | plotnikovo
# Processing Record 49 of Set 13 | roma
# Processing Record 50 of Set 13 | belaya gora
# Processing Record 1 of Set 14 | blagoyevo
# Processing Record 2 of Set 14 | kieta
# Processing Record 3 of Set 14 | griffith
# Processing Record 4 of Set 14 | nardaran
# Processing Record 5 of Set 14 | broome
# Processing Record 6 of Set 14 | mahibadhoo
# Processing Record 7 of Set 14 | barcelos
# Processing Record 8 of Set 14 | cidreira
# Processing Record 9 of Set 14 | kharan
# Processing Record 10 of Set 14 | biltine
# Processing Record 11 of Set 14 | kamyzyak
# Processing Record 12 of Set 14 | agadez
# Processing Record 13 of Set 14 | anadyr
# Processing Record 14 of Set 14 | kholm
# Processing Record 15 of Set 14 | rockland
# Processing Record 16 of Set 14 | fare
# Processing Record 17 of Set 14 | makakilo city
# Processing Record 18 of Set 14 | bentiu
# Processing Record 19 of Set 14 | skrunda
# Processing Record 20 of Set 14 | korsakov
# Processing Record 21 of Set 14 | andilamena
# Processing Record 22 of Set 14 | huimilpan
# Processing Record 23 of Set 14 | pokrovskoye
# Processing Record 24 of Set 14 | kamariotissa
# Processing Record 25 of Set 14 | shisui
# Processing Record 26 of Set 14 | elbistan
# Processing Record 27 of Set 14 | knyaginino
# Processing Record 28 of Set 14 | valdepenas
# Processing Record 29 of Set 14 | amapa
# Processing Record 30 of Set 14 | manvi
# Processing Record 31 of Set 14 | alice springs
# Processing Record 32 of Set 14 | tashtagol
# Processing Record 33 of Set 14 | quatre cocos
# Processing Record 34 of Set 14 | saldanha
# Processing Record 35 of Set 14 | olinda
# Processing Record 36 of Set 14 | oda
# Processing Record 37 of Set 14 | rio grande
# Processing Record 38 of Set 14 | george
# Processing Record 39 of Set 14 | huarmey
# Processing Record 40 of Set 14 | imbituba
# Processing Record 41 of Set 14 | shakawe
# Processing Record 42 of Set 14 | bridlington
# Processing Record 43 of Set 14 | madrid
# Processing Record 44 of Set 14 | general pico
# Processing Record 45 of Set 14 | tall kayf
# Processing Record 46 of Set 14 | mitsamiouli
# Processing Record 47 of Set 14 | dali
# Processing Record 48 of Set 14 | lewisporte
# Processing Record 49 of Set 14 | stokmarknes
# Processing Record 50 of Set 14 | irondequoit
# Processing Record 1 of Set 15 | khorixas
# Processing Record 2 of Set 15 | sioux lookout
# Processing Record 3 of Set 15 | charters towers
# Processing Record 4 of Set 15 | zhangye
# Processing Record 5 of Set 15 | verkhoyansk
# Processing Record 6 of Set 15 | chara
# Processing Record 7 of Set 15 | muyinga
# Processing Record 8 of Set 15 | lensk
# Processing Record 9 of Set 15 | tual
# Processing Record 10 of Set 15 | talawdi
# City not found. Skipping...
# Processing Record 11 of Set 15 | pacific grove
# Processing Record 12 of Set 15 | san vicente
# Processing Record 13 of Set 15 | maneadero
# Processing Record 14 of Set 15 | starominskaya
# Processing Record 15 of Set 15 | puerto madero
# Processing Record 16 of Set 15 | clonakilty
# Processing Record 17 of Set 15 | banyo
# Processing Record 18 of Set 15 | hit
# Processing Record 19 of Set 15 | fernandina beach
# Processing Record 20 of Set 15 | oussouye
# Processing Record 21 of Set 15 | goderich
# Processing Record 22 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 23 of Set 15 | moranbah
# Processing Record 24 of Set 15 | lusambo
# Processing Record 25 of Set 15 | itoman
# Processing Record 26 of Set 15 | vanimo
# Processing Record 27 of Set 15 | coruripe
# Processing Record 28 of Set 15 | ciechanow
# Processing Record 29 of Set 15 | mercaderes
# Processing Record 30 of Set 15 | sinnamary
# Processing Record 31 of Set 15 | port shepstone
# Processing Record 32 of Set 15 | carupano
# Processing Record 33 of Set 15 | terrace bay
# Processing Record 34 of Set 15 | shakhtinsk
# Processing Record 35 of Set 15 | mugur-aksy
# Processing Record 36 of Set 15 | dwarka
# Processing Record 37 of Set 15 | allende
# Processing Record 38 of Set 15 | cabedelo
# Processing Record 39 of Set 15 | elko
# Processing Record 40 of Set 15 | seoul
# Processing Record 41 of Set 15 | tiarei
# Processing Record 42 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 15 | mangan
# Processing Record 44 of Set 15 | novoagansk
# Processing Record 45 of Set 15 | chernyshkovskiy
# Processing Record 46 of Set 15 | sambava
# Processing Record 47 of Set 15 | namibe
# Processing Record 48 of Set 15 | samarai
# Processing Record 49 of Set 15 | balkhash
# Processing Record 50 of Set 15 | soavinandriana
# Processing Record 1 of Set 16 | simplicio mendes
# Processing Record 2 of Set 16 | aranos
# Processing Record 3 of Set 16 | kempsey
# Processing Record 4 of Set 16 | izumo
# Processing Record 5 of Set 16 | bialystok
# Processing Record 6 of Set 16 | damaturu
# Processing Record 7 of Set 16 | biscarrosse
# Processing Record 8 of Set 16 | fuerte olimpo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 704

# %%
# convert list of dictionaries to a pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Norman Wells      CA  65.2820 -126.8329     23.04        93
# 1                Taltal      CL -25.4000  -70.4833     64.65        67
# 2               Ushuaia      AR -54.8000  -68.3000     35.26        64
# 3              Karasjok      NO  69.4719   25.5112     14.11        98
# 4              Waingapu      ID  -9.6567  120.2641     78.64        84
# 5                 Vardo      NO  70.3705   31.1107     25.00        58
# 6  Vila Franca Do Campo      PT  37.7167  -25.4333     63.01        77
# 7                Kodiak      US  57.7900 -152.4072     44.10        79
# 8          Port Lincoln      AU -34.7333  135.8667     55.31        67
# 9               Sechura      PE  -5.5569  -80.8222     74.12        60
#
#    Cloudiness  Wind Speed Current Description
# 0          90        4.61     overcast clouds
# 1          24        5.12          few clouds
# 2          75       21.85          heavy snow
# 3         100        2.13     overcast clouds
# 4          79        1.48       broken clouds
# 5          49        5.86          light snow
# 6           0        5.99           clear sky
# 7          17        6.80          few clouds
# 8           0       14.70           clear sky
# 9          45       16.35    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
